# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %run Interpolation.ipynb
#%load Interpolation.ipynb ---> loads a jupyter notebook
#from Interpolation.ipynb import  Surface_density


t_arr = np.array([ i for i in range(0,51)])
a = np.zeros((51,1024),dtype=float)
R = np.loadtxt("domain_y.dat") # Radial grid positions



for i in range(0,51): #Array with a[i] = i*20 orbits
    
    if i<10:

        a[i] = np.loadtxt("dens000000"+ str(i) +  ".txt")

    else:
    
        a[i] = np.loadtxt("dens00000"+ str(i)  + ".txt")

# %%
print Surface_density(2.407985e+14,50)
df = pd.DataFrame(a[50],R)

print df
# Out:
# 12.755627095075905
#                       0
# 2.407985e+14  12.755628
# 2.415996e+14  12.719379
# 2.424034e+14  12.683177
# 2.432099e+14  12.647059
# 2.440190e+14  12.611033
# 2.448309e+14  12.575099
# 2.456455e+14  12.539258
# 2.464627e+14  12.503508
# 2.472827e+14  12.467851
# 2.481054e+14  12.432286
# 2.489308e+14  12.396812
# 2.497591e+14  12.361430
# 2.505900e+14  12.326139
# 2.514237e+14  12.290938
# 2.522602e+14  12.255828
# 2.530995e+14  12.220808
# 2.539416e+14  12.185879
# 2.547864e+14  12.151039
# 2.556341e+14  12.116288
# 2.564846e+14  12.081627
# 2.573379e+14  12.047055
# 2.581941e+14  12.012572
# 2.590531e+14  11.978178
# 2.599150e+14  11.943872
# 2.607797e+14  11.909654
# 2.616473e+14  11.875524
# 2.625178e+14  11.841484
# 2.633912e+14  11.807534
# 2.642675e+14  11.773676
# 2.651467e+14  11.739915
# ...                 ...
# 6.538829e+15   0.074046
# 6.560584e+15   0.073164
# 6.582410e+15   0.072328
# 6.604310e+15   0.071522
# 6.626282e+15   0.070740
# 6.648328e+15   0.069972
# 6.670448e+15   0.069200
# 6.692640e+15   0.068411
# 6.714907e+15   0.067602
# 6.737247e+15   0.066786
# 6.759662e+15   0.065981
# 6.782151e+15   0.065187
# 6.804716e+15   0.064381
# 6.827355e+15   0.063546
# 6.850069e+15   0.062685
# 6.872860e+15   0.061817
# 6.895725e+15   0.060956
# 6.918668e+15   0.060111
# 6.941686e+15   0.059284
# 6.964782e+15   0.058474
# 6.987953e+15   0.057677
# 7.011202e+15   0.056891
# 7.034528e+15   0.056114
# 7.057933e+15   0.055347
# 7.081414e+15   0.054587
# 7.104974e+15   0.053836
# 7.128612e+15   0.053093
# 7.152329e+15   0.052358
# 7.176125e+15   0.051629
# 7.200000e+15   0.050903
#
# [1024 rows x 1 columns]
